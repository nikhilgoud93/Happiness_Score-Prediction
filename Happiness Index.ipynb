# %% [markdown]
# # Exploratary Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Feature Engineering

# %%
df=pd.read_csv('happy.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df['Country'].groupby(df['Region']).value_counts().head(40)
# Out:
# Region                       Country
# Australia and New Zealand    Australia                 1
#                              New Zealand               1
# Central and Eastern Europe   Albania                   1
#                              Armenia                   1
#                              Azerbaijan                1
#                              Belarus                   1
#                              Bosnia and Herzegovina    1
#                              Bulgaria                  1
#                              Croatia                   1
#                              Czech Republic            1
#                              Estonia                   1
#                              Georgia                   1
#                              Hungary                   1
#                              Kazakhstan                1
#                              Kosovo                    1
#                              Kyrgyzstan                1
# ...

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
from cycler import cycler
plt.style.use('ggplot')
fig= plt.figure(figsize=(25,5))
plt.bar(df['Region'], df['Happiness Score'],label='Happiness score')
plt.title("Region wise happiness score")
plt.xlabel('Region')
plt.ylabel('Happiness Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [raw]
# 1.From the above graph we can conclude that Western europe is having Highest Happiness score and Southern asia having
#   the lowest value.

# %%
from cycler import cycler
plt.style.use('seaborn')
fig= plt.figure(figsize=(25,10))
plt.bar(df['Region'],df['Country'],label='No.of countries')
plt.title("No. of countries in each region")
plt.xlabel('Region')
plt.ylabel('No. of countries')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df1=df.iloc[:,4:]

# %%
df1.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
for i in df1.columns:
    plt.hist(df1[i])
    plt.xlabel(i)
    plt.show()

# %%
df1.skew()
# Out:
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
for i in df1.columns:
    sns.distplot(df1[i])
    plt.xlabel(i)  
    plt.show()

# %%
df['Happiness Score'].plot.hist(bins=10)
plt.xlabel('Happiness Score')
plt.title('Distribution of Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# Observations
# 1.The regions which are having less number of countries are performing good.
# 2.There are no null values in the dataset
# 3.There are extreme values in some features however we cannot ignore them as the extreme values depend on the countries and plays an important for some specific values.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,5))
plt.title('Regionwise Happiness Score')
sns.barplot(df['Region'],df['Happiness Score'],label='Happiness Score')
plt.legend()

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [raw]
# Observation on Skewness:
#
# The skewness is high for the features Standard Error, Trust (Government Corruption), Generosity.
# As the values are negative we can ignore the skewness of the data this features as it gives negative values when we apply log function.

# %%
df['Generosity']
# Out:
# 0      0.29678
# 1      0.43630
# 2      0.34139
# 3      0.34699
# 4      0.45811
#         ...
# 153    0.22628
# 154    0.18260
# 155    0.47179
# 156    0.19727
# 157    0.16681
# Name: Generosity, Length: 158, dtype: float64

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
list=['Country', 'Happiness Rank', 'Happiness Score','Standard Error']
df1=df.drop(list,axis=1)

# %%
df1
# Out:
#                               Region  Economy (GDP per Capita)   Family  \
# 0                     Western Europe                   1.39651  1.34951
# 1                     Western Europe                   1.30232  1.40223
# 2                     Western Europe                   1.32548  1.36058
# 3                     Western Europe                   1.45900  1.33095
# 4                      North America                   1.32629  1.32261
# ..                               ...                       ...      ...
# 153               Sub-Saharan Africa                   0.22208  0.77370
# 154               Sub-Saharan Africa                   0.28665  0.35386
# 155  Middle East and Northern Africa                   0.66320  0.47489
# 156               Sub-Saharan Africa                   0.01530  0.41587
# 157               Sub-Saharan Africa                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
for i in df.columns:
    plt.figure(figsize=(20,5))
    sns.barplot(df[i],df['Happiness Score'],label='Happiness Score')
    plt.title(i)
    plt.legend()
    plt.show()

# %%
for i in df.columns:
    from cycler import cycler
    plt.style.use('ggplot')
    plt.figure(figsize=(15,5))
    sns.scatterplot(df[i],df['Happiness Score'],label='Happiness Score')
    plt.title(i)
    plt.legend()
    plt.show()

# %% [markdown]
# Observation from Bivatriate Analysis:
# 1. Happiness Rank can be removed from the data as it is completely not related to calculate the Happiness score
# 2. We can drop the country

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
s_asia = df[df.Region=='Southern Asia']
e_asia = df[df.Region=='Eastern Asia']
se_asia = df[df.Region=='Southeastern Asia']

asia = pd.concat([s_asia, e_asia, se_asia],axis=0)

# %%
asia.head()
# Out:
#         Country         Region  Happiness Rank  Happiness Score  \
# 78       Bhutan  Southern Asia              79            5.253
# 80     Pakistan  Southern Asia              81            5.194
# 108  Bangladesh  Southern Asia             109            4.694
# 116       India  Southern Asia             117            4.565
# 120       Nepal  Southern Asia             121            4.514
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 78          0.03225                   0.77042  1.10395
# 80          0.03726                   0.59543  0.41411
# 108         0.03077                   0.39753  0.43106
# 116         0.02043                   0.64499  0.38174
# 120         0.03607                   0.35997  0.86449
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 78                    0.57407  0.53206                        0.15445
# 80                    0.51466  0.12102                        0.10464
# ...

# %%
from cycler import cycler
plt.style.use('ggplot')
sns.heatmap(df.corr(),annot=True)

# %% [raw]
# ## From above we corrleation we can can conclude that we can drop Standar Error, Happiness Rank. As the corrleation between them with the happiness is very negative.

# %% [markdown]
# # Feature Selection

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
col=['Country','Happiness Rank','Standard Error','Region']
df=df.drop(col,axis=1)

# %%
df.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
x=df.iloc[:,1:]
print('Shape of x is',x.shape)
# Out:
# Shape of x is (158, 7)

# %%
y=df.iloc[:,0:1]
print('Shape of y is', y.shape)
# Out:
# Shape of y is (158, 1)

# %%
y.head()
# Out:
#    Happiness Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
df1=std.fit_transform(x,y)

# %%
df1=pd.DataFrame(df,columns=['Happiness Score','Economy (GDP per Capita)', 'Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)',
    'Generosity','Dystopia Residual'])

# %%
df.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
df1=std.fit_transform(x,y)

# %%
df1=pd.DataFrame(df1)
df1=df1.rename(columns={0:'Happiness Score',1:'Economy (GDP per Capita)',2:'Family',3:'Health (Life Expectancy)',4:'Freedom',5:'Trust (Government Corruption)',
    6:'Generosity',7:'Dystopia Residual'})

# %%
df1.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)    Family  \
# 0         1.369621                  1.320281  1.263408
# 1         1.135226                  1.514458  1.289434
# 2         1.192861                  1.361054  0.992229
# 3         1.525130                  1.251922  1.035145
# 4         1.194876                  1.221204  1.118054
#
#    Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                  1.577438  2.309652                       0.471040
# 1                  1.332456 -0.016480                       1.575856
# 2                  1.469659  2.842774                       0.824293
# 3                  1.605131  1.852081                       0.868638
# 4                  1.360416  1.555725                       1.748563
#
#    Generosity
# 0    0.758258
# 1    1.092857
# 2    0.712335
# 3    0.663893
# 4    0.639337

# %%
x1=df1.iloc[:,1:]
print('Shape of x is',x1.shape)
# Out:
# Shape of x is (158, 6)

# %%
x1.head()
# Out:
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.320281  1.263408                  1.577438  2.309652
# 1                  1.514458  1.289434                  1.332456 -0.016480
# 2                  1.361054  0.992229                  1.469659  2.842774
# 3                  1.251922  1.035145                  1.605131  1.852081
# 4                  1.221204  1.118054                  1.360416  1.555725
#
#    Trust (Government Corruption)  Generosity
# 0                       0.471040    0.758258
# 1                       1.575856    1.092857
# 2                       0.824293    0.712335
# 3                       0.868638    0.663893
# 4                       1.748563    0.639337

# %%
y1=df1.iloc[:,0:1]
print('Shape of y is',y1.shape)
# Out:
# Shape of y is (158, 1)

# %%
y1.head()
# Out:
#    Happiness Score
# 0         1.369621
# 1         1.135226
# 2         1.192861
# 3         1.525130
# 4         1.194876

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
maxr2_score=0
for ran in range(42,101):
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=ran)
    lr=LinearRegression()
    lr.fit(xtrain,ytrain)
    pred=lr.predict(xtest)
    r2_scr= r2_score(ytest,pred)
    print('r2_score for the corresponding random_state',ran,'is',r2_scr)
    if r2_scr>maxr2_score:
        maxr2_score=r2_scr
        final_rscore=ran
print()
print()
print('Max r_state for the Corresponding random_state of',final_rscore, 'is',maxr2_score)
# Out:
# r2_score for the corresponding random_state 42 is 0.9999999484481188
# r2_score for the corresponding random_state 43 is 0.9999999410560375
# r2_score for the corresponding random_state 44 is 0.9999999505305747
# r2_score for the corresponding random_state 45 is 0.9999999434538785
# r2_score for the corresponding random_state 46 is 0.9999999451710723
# r2_score for the corresponding random_state 47 is 0.9999999154061283
# r2_score for the corresponding random_state 48 is 0.9999999205297967
# r2_score for the corresponding random_state 49 is 0.9999999303083521
# r2_score for the corresponding random_state 50 is 0.9999999324328823
# r2_score for the corresponding random_state 51 is 0.9999999262534341
# r2_score for the corresponding random_state 52 is 0.999999947885814
# r2_score for the corresponding random_state 53 is 0.9999999206375931
# r2_score for the corresponding random_state 54 is 0.9999999651025517
# r2_score for the corresponding random_state 55 is 0.9999999332224478
# ...

# %%
from sklearn.linear_model import LinearRegression
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=72)
lr=LinearRegression()
lr.fit(xtrain,ytrain)
pred=lr.predict(xtest)

# %%
pred
# Out:
# array([[6.4546448 ],
#        [6.50508902],
#        [6.75013344],
#        [3.57457097],
#        [7.22569695],
#        [6.78623335],
#        [3.81919914],
#        [5.75440531],
#        [6.86719329],
#        [2.83894062],
#        [3.9947625 ],
#        [7.42688414],
#        [7.11951381],
#        [5.12312118],
#        [7.56087104],
#        [5.79060372],
#        [4.19428222],
#        [4.87598703],
#        [5.83266723],
#        [4.51779197],
#        [6.00269346],
#        [6.26927132],
#        [3.65589574],
#        [3.95560429],
#        [5.39868998],
#        [6.4111726 ],
#        [6.57506173],
#        [5.07326709],
#        [3.67780234],
#        [7.52217813],
#        [7.28399155],
#        [3.84494999]])

# %%
type(pred)
# Out:
# numpy.ndarray

# %%
pred=pd.DataFrame(pred)
pred=pred.rename(columns={0:'Predicted_Happiness Score'})

# %%
pred.head()
# Out:
#    Predicted_Happiness Score
# 0                   6.454645
# 1                   6.505089
# 2                   6.750133
# 3                   3.574571
# 4                   7.225697

# %%
ytest.head()
# Out:
#      Happiness Score
# 33             6.455
# 30             6.505
# 25             6.750
# 152            3.575
# 11             7.226

# %%
pred.head()
# Out:
#    Predicted_Happiness Score
# 0                   6.454645
# 1                   6.505089
# 2                   6.750133
# 3                   3.574571
# 4                   7.225697

# %%
print('r2_score for the data is',r2_score(ytest,pred))
# Out:
# r2_score for the data is 0.9999999661502993

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("error:")

print('Mean absolute error:', mean_absolute_error(ytest,pred))
print('Mean squared error:', mean_squared_error(ytest,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest,pred)))
# Out:
# error:
# Mean absolute error: 0.00022104063152131315
# Mean squared error: 6.539196416770238e-08
# Root Mean Squared Error: 0.00025571852527281314

# %%
## Root Mean Squared error is 0.0002557. The value is almost negligible and the model is performing well.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cross=cross_val_score(lr,x,y,cv=5)

# %%
cross.mean()
# Out:
# 0.9999981947416542

# %% [markdown]
# # Grid Search CV applied for Lasso and Ridge to figure best alpha parameter

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV
ls=Lasso()
parameters={'alpha':[1,0.1,0.01,0.001,0.0001,0.02,0.003,0.049,0.167]}
ridge=Ridge()
clf=GridSearchCV(lasso,parameters)
clf.fit(x,y)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0.02, 0.003,
#                                    0.049, 0.167]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(clf.best_params_)
# Out:
# {'alpha': 0.0001}

# %%
parameters={'alpha':[1,0.1,0.01,0.001,0.0001,0.02,0.003,0.049,0.167]}
ridge=Ridge()
dlf=GridSearchCV(ridge,parameters)
dlf.fit(x,y)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0.02, 0.003,
#                                    0.049, 0.167]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best parameter of alpha for ridge regression is',dlf.best_params_)
# Out:
# Best parameter of alpha for ridge regression is {'alpha': 0.0001}

# %% [markdown]
# # Lasso, Ridge and Linear Regression on the model

# %%
from sklearn.linear_model import Lasso, Ridge
lasso=Lasso(alpha=0.0001)
ridge=Ridge(alpha=0.0001)
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=72)
models=[lasso,ridge,lr]
for i in models:
    i.fit(xtrain,ytrain)
    predi=i.predict(xtest)
    print('\n')
    print('****************Model********************',i)
    print('\n')
    print('score of the training models', i.score(xtrain,ytrain))
    print('r2 score of the model is',r2_score(ytest,predi))
    print('Mean absolute error:', mean_absolute_error(ytest,predi))
    print('Mean squared error:', mean_squared_error(ytest,predi))
    print('Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest,predi)))
print()
print()
# Out:
# ****************Model******************** Lasso(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
#
#
# score of the training models 0.9999988143388645
# r2 score of the model is 0.9999990902800736
# Mean absolute error: 0.0010320239635248085
# Mean squared error: 1.757426846633958e-06
# Root Mean Squared Error: 0.0013256797677546257
#
#
# ****************Model******************** Ridge(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
#
#
# score of the training models 0.9999999299641131
# r2 score of the model is 0.9999999661100472
# Mean absolute error: 0.0002219481404492768
# Mean squared error: 6.54697245611928e-08
# Root Mean Squared Error: 0.00025587052304083954
#
#
# ...

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib
joblib.dump(lr,'happyfile.obj')
# Out:
# ['happyfile.obj']
